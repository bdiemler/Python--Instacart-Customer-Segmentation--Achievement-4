# %% [markdown]
# # 01 Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Python Data Types

# %% [markdown]
# ## Results of 100 by adding or subtracting numeric variables

# %%
x = 50

# %%
y = 20

# %%
z = 30

# %%
x + x
# Out:
# 100

# %%
x + y + z
# Out:
# 100

# %%
x + x + x - y - z
# Out:
# 100

# %% [markdown]
# ## 2 Floating-point variables and divide by each other

# %%
a = 18.75

# %%
b = 6.25

# %%
a / b
# Out:
# 3.0

# %% [markdown]
# ## Short word made of separate strings

# %%
c = 'Star'

# %%
d = 'dust '

# %%
c+d
# Out:
# 'Stardust'

# %% [markdown]
# ## 2 Short sentences made of separate strings

# %%
e = 'We will be '

# %%
f = 'after the crash'

# %%
g = 'data analysts in the future'

# %%
e + g
# Out:
# 'We will be data analysts in the future'

# %%
e + c + d + f
# Out:
# 'We will be Stardust after the crash'

# %% [markdown]
# ## Bonus Task

# %%
c * 100
# Out:
# '...'
