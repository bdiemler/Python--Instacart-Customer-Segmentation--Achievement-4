# %% [markdown]
# # Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data Sets

# %%
path = r'C:\Users\Aricia\MM-2020 Instacart Basket Analysis'

# %%
# Import Orders Checked Data
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = False)

# %%
# Import Orders Product Data
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)

# %%
# Check the output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Check the output df ords
df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   2                  8                    -1.0
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0

# %%
# Dropping the unnamed columns created due to Index when exporting
columns_to_drop = ['Unnamed: 0.1', 'Unnamed: 0']

# %%
# Delete the columns and update the DataFrame using 'inplace=True'
df_ords.drop(columns=columns_to_drop, inplace=True)

# %%
# Check the output df ords
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                    -1.0
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Check the shape for df_ords_prior
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
# Check the shape for df_ords
df_ords.shape
# Out:
# (3421083, 6)

# %% [markdown]
# # Merging dataframes

# %%
# Create a new dataframe combining both: df_merged_large
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
# Check new dataframe
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                    -1.0         196                  1          0   both
# 1                    -1.0       14084                  2          0   both
# 2                    -1.0       12427                  3          0   both
# 3                    -1.0       26088                  4          0   both
# 4                    -1.0       26405                  5          0   both

# %%
# Checking value counts for full or parcial match - not accurate as it merger inner
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# Best practice: always check your data using a outer join as well to make sure you have a full data.
# df_merged_outer = df_ords.merge(df_ords_prior, on='order_id', how='outer', indicator=True)

# %% [markdown]
# # Exporting data

# %%
# Export data to pkl
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
