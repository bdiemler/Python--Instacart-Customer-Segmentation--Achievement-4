# %% [markdown]
# # Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data Sets

# %%
path = r'C:\Users\Aricia\MM-2020 Instacart Basket Analysis'

# %%
# Importing updated Orders Products Merge 
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_ords_prods_merge.pkl'))

# %%
# Checking number of columns and rows
ords_prods_merge.shape
# Out:
# (32434212, 19)

# %%
# Checking columns name
ords_prods_merge.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices',
#        'order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'add_to_cart_order',
#        'reordered', '_merge', 'Merge_flag', 'price_range_loc', 'busiest_day',
#        'busiest_days', 'busiest_period_of_day'],
#       dtype='object')

# %%
# Createing a subset for a smaller sample of data
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head(5)
# Out:
# C:\Users\Aricia\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge Merge_flag  \
# 0                     3.0                  5          0   both       both
# 1                    20.0                  1          1   both       both
# 2                     6.0                 20          0   both       both
# 3                    -1.0                 10          0   both       both
# 4                     9.0                 11          1   both       both
#
#      price_range_loc     busiest_day  busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy  Regular days           Most orders
# 1  Mid-range product  Regularly busy  Regular days        Average orders
# 2  Mid-range product     Busiest day  Busiest days        Average orders
# 3  Mid-range product  Regularly busy  Slowest days        Average orders
# 4  Mid-range product      Least busy  Slowest days        Average orders

# %% [markdown]
# ## Grouping data with pandas

# %%
# Splitting product names into columns
df.groupby('product_name')

# %% [markdown]
# ## Aggregating data with agg()

# %%
# Split data into groups based on department and apply add to obtain mean values for the order number
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.562844
# 2                17.518895
# 3                16.907152
# 4                17.537934
# 5                14.894521
# 6                16.658449
# 7                17.072954
# 8                14.942021
# 9                15.447580
# 10               18.681852
# 11               15.352278
# 12               14.327957
# 13               16.578690
# 14               16.666369
# 15               16.153766
# 16               17.768070
# 17               15.602964
# 18               19.674252
# 19               16.924344
# 20               16.292631
# 21               25.535596

# %%
# Alternative function
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.562844
# 2     17.518895
# 3     16.907152
# 4     17.537934
# 5     14.894521
# 6     16.658449
# 7     17.072954
# 8     14.942021
# 9     15.447580
# 10    18.681852
# 11    15.352278
# 12    14.327957
# 13    16.578690
# 14    16.666369
# 15    16.153766
# 16    17.768070
# 17    15.602964
# 18    19.674252
# 19    16.924344
# 20    16.292631
# 21    25.535596
# Name: order_number, dtype: float64

# %%
# Multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.562844   1  99
# 2                17.518895   1  96
# 3                16.907152   1  99
# 4                17.537934   1  99
# 5                14.894521   1  99
# 6                16.658449   1  99
# 7                17.072954   1  99
# 8                14.942021   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.352278   1  99
# 12               14.327957   1  99
# 13               16.578690   1  99
# 14               16.666369   1  99
# 15               16.153766   1  99
# 16               17.768070   1  99
# 17               15.602964   1  99
# 18               19.674252   1  99
# 19               16.924344   1  99
# 20               16.292631   1  99
# 21               25.535596   1  98

# %% [markdown]
# ## Aggregating data with transform ()

# %%
# Create flags for the data
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\Aricia\AppData\Local\Temp\ipykernel_54852\626152994.py:2: FutureWarning: The provided callable <function max at 0x000002838A237060> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
# C:\Users\Aricia\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    3139998      138            28                   6                 11
# 1    1977647      138            30                   6                 17
# 2     389851      709             2                   0                 21
# 3     652770      764             1                   3                 13
# 4    1813452      764             3                   4                 17
# 5    1701441      777            16                   1                  7
# 6    1871483      825             3                   2                 14
# 7    1290456      910            12                   3                 10
# 8     369558     1052            10                   1                 20
# 9     589712     1052            15                   1                 12
# 10   1798115     1379             1                   5                 11
# 11    497193     1480            36                   3                 13
# 12   1727826     1480            38                   4                 13
# 13   2694698     1480            39                   2                 12
# 14   3171753     1494             6                   3                 10
#
#     days_since_prior_order  add_to_cart_order  reordered _merge Merge_flag  \
# 0                      3.0                  5          0   both       both
# 1                     20.0                  1          1   both       both
# 2                      6.0                 20          0   both       both
# 3                     -1.0                 10          0   both       both
# 4                      9.0                 11          1   both       both
# 5                     26.0                  7          0   both       both
# 6                     30.0                  2          0   both       both
# 7                     30.0                  1          0   both       both
# 8                     19.0                  1          0   both       both
# 9                     15.0                  2          1   both       both
# 10                    -1.0                  1          0   both       both
# 11                     7.0                  1          0   both       both
# 12                     7.0                  3          1   both       both
# 13                    12.0                  4          1   both       both
# 14                     2.0                  8          0   both       both
#
#       price_range_loc     busiest_day  busiest_days busiest_period_of_day  \
# 0   Mid-range product  Regularly busy  Regular days           Most orders
# 1   Mid-range product  Regularly busy  Regular days        Average orders
# 2   Mid-range product     Busiest day  Busiest days        Average orders
# 3   Mid-range product  Regularly busy  Slowest days        Average orders
# 4   Mid-range product      Least busy  Slowest days        Average orders
# 5   Mid-range product  Regularly busy  Busiest days        Average orders
# 6   Mid-range product  Regularly busy  Regular days        Average orders
# 7   Mid-range product  Regularly busy  Slowest days           Most orders
# 8   Mid-range product  Regularly busy  Busiest days        Average orders
# 9   Mid-range product  Regularly busy  Busiest days        Average orders
# 10  Mid-range product  Regularly busy  Regular days           Most orders
# 11  Mid-range product  Regularly busy  Slowest days        Average orders
# 12  Mid-range product      Least busy  Slowest days        Average orders
# 13  Mid-range product  Regularly busy  Regular days        Average orders
# 14  Mid-range product  Regularly busy  Slowest days           Most orders
#
#     max_order
# 0          32
# 1          32
# 2           5
# 3           3
# 4           3
# 5          26
# 6           9
# 7          12
# 8          20
# 9          20
# 10         10
# 11         43
# 12         43
# 13         43
# 14         13

# %% [markdown]
# ## Deriving columns withloc()

# %%
# Creating flag for loyal customers

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking frequency of loyalty-flags
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: count, dtype: int64

# %%
# Checking column for data accuracy
ords_prods_merge['loyalty_flag']
# Out:
# 0           Regular customer
# 1           Regular customer
# 2               New customer
# 3               New customer
# 4               New customer
#                   ...
# 32434207        New customer
# 32434208        New customer
# 32434209    Regular customer
# 32434210    Regular customer
# 32434211    Regular customer
# Name: loyalty_flag, Length: 32434212, dtype: object

# %%
# Check head of limited columns
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# 20     1540  Regular customer             7
# 21     1540  Regular customer             8
# 22     1540  Regular customer             9
# 23     1540  Regular customer            14
# 24     1540  Regular customer            15
# 25     1540  Regular customer            18
# 26     1540  Regular customer            19
# 27     1540  Regular customer            20
# 28     1540  Regular customer            21
# 29     1540  Regular customer            22
# 30     1540  Regular customer            24
# 31     1540  Regular customer            25
# 32     1540  Regular customer            27
# 33     1540  Regular customer            28
# 34     1598      New customer             1
# 35     1598      New customer             2
# 36     1598      New customer             3
# 37     1647      New customer             1
# 38     1647      New customer             4
# 39     1647      New customer             6
# 40     1647      New customer             8
# 41     1647      New customer             9
# 42     2833      New customer             1
# 43     2850  Regular customer             7
# 44     2857  Regular customer            24
# 45     3010  Regular customer             5
# 46     3029      New customer             1
# 47     3395      New customer             4
# 48     3904      New customer             1
# 49     4006    Loyal customer             2
# 50     4006    Loyal customer             3
# 51     4006    Loyal customer             5
# 52     4006    Loyal customer             9
# 53     4006    Loyal customer            12
# 54     4122  Regular customer            11
# 55     4141      New customer             2
# 56     4343      New customer             1
# 57     4553      New customer             3
# 58     4845  Regular customer             6
# 59     6866      New customer             1
